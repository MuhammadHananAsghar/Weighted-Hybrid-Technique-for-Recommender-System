# %% [markdown]
# **How Recomended Systems Are Made in Past?**
#
# Implementated By Muhammad Hanan Asghar

# %%
from google.colab import files

uploaded = files.upload()

for fn in uploaded.keys():
  print('User uploaded file "{name}" with length {length} bytes'.format(
      name=fn, length=len(uploaded[fn])))
# Out:
#      <input type="file" id="files-95a83909-d8a7-4f84-a21c-32a4fae746eb" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-95a83909-d8a7-4f84-a21c-32a4fae746eb">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving kaggle.json to kaggle.json
# User uploaded file "kaggle.json" with length 75 bytes

# %%
import os
os.environ['KAGGLE_CONFIG_DIR'] = "/content"

# %%
# !kaggle datasets download -d tmdb/tmdb-movie-metadata
# Out:
# ...
#  56% 5.00M/8.89M [00:00<00:00, 21.4MB/s]
# 100% 8.89M/8.89M [00:00<00:00, 35.2MB/s]

# %%
#unzipping the zip files and deleting the zip files
# !unzip \*.zip  && rm *.zip
# Out:
# Archive:  tmdb-movie-metadata.zip
# replace tmdb_5000_credits.csv? [y]es, [n]o, [A]ll, [N]one, [r]ename: A
#   inflating: tmdb_5000_credits.csv
#   inflating: tmdb_5000_movies.csv

# %%
import pandas as pd
import numpy as np

# %%
credits = pd.read_csv("/content/tmdb_5000_credits.csv")

movies = pd.read_csv("/content/tmdb_5000_movies.csv")

# %%
credits.head()
# Out:
#    movie_id  ...                                               crew
# 0     19995  ...  [{"credit_id": "52fe48009251416c750aca23", "de...
# 1       285  ...  [{"credit_id": "52fe4232c3a36847f800b579", "de...
# 2    206647  ...  [{"credit_id": "54805967c3a36829b5002c41", "de...
# 3     49026  ...  [{"credit_id": "52fe4781c3a36847f81398c3", "de...
# 4     49529  ...  [{"credit_id": "52fe479ac3a36847f813eaa3", "de...
#
# [5 rows x 4 columns]

# %%
movies.head()
# Out:
#       budget  ... vote_count
# 0  237000000  ...      11800
# 1  300000000  ...       4500
# 2  245000000  ...       4466
# 3  250000000  ...       9106
# 4  260000000  ...       2124
#
# [5 rows x 20 columns]

# %%
print("Credits:",credits.shape)
print("Movies:",movies.shape)
# Out:
# Credits: (4803, 4)
# Movies: (4803, 20)

# %% [markdown]
# **Let's Combine Our Dataset**

# %%
credits_column_renamed = credits.rename(index=str, columns={"movie_id":"id"})
movies_merge = movies.merge(credits_column_renamed, on="id")
movies_merge.head()
# Out:
#       budget  ...                                               crew
# 0  237000000  ...  [{"credit_id": "52fe48009251416c750aca23", "de...
# 1  300000000  ...  [{"credit_id": "52fe4232c3a36847f800b579", "de...
# 2  245000000  ...  [{"credit_id": "54805967c3a36829b5002c41", "de...
# 3  250000000  ...  [{"credit_id": "52fe4781c3a36847f81398c3", "de...
# 4  260000000  ...  [{"credit_id": "52fe479ac3a36847f813eaa3", "de...
#
# [5 rows x 23 columns]

# %%
print("Merged Movies:", movies_merge.shape)
# Out:
# Merged Movies: (4803, 23)

# %%
# Removing Unwanted Columns

movies_cleaned_df = movies_merge.drop(columns=['homepage', 'title_x', 'title_y', 'status','production_countries'])
movies_cleaned_df.head()
# Out:
#       budget  ...                                               crew
# 0  237000000  ...  [{"credit_id": "52fe48009251416c750aca23", "de...
# 1  300000000  ...  [{"credit_id": "52fe4232c3a36847f800b579", "de...
# 2  245000000  ...  [{"credit_id": "54805967c3a36829b5002c41", "de...
# 3  250000000  ...  [{"credit_id": "52fe4781c3a36847f81398c3", "de...
# 4  260000000  ...  [{"credit_id": "52fe479ac3a36847f813eaa3", "de...
#
# [5 rows x 18 columns]

# %%
movies_cleaned_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4803 entries, 0 to 4802
# Data columns (total 18 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   budget                4803 non-null   int64
#  1   genres                4803 non-null   object
#  2   id                    4803 non-null   int64
#  3   keywords              4803 non-null   object
#  4   original_language     4803 non-null   object
#  5   original_title        4803 non-null   object
#  6   overview              4800 non-null   object
#  7   popularity            4803 non-null   float64
#  8   production_companies  4803 non-null   object
#  9   release_date          4802 non-null   object
#  10  revenue               4803 non-null   int64
#  11  runtime               4801 non-null   float64
#  12  spoken_languages      4803 non-null   object
#  13  tagline               3959 non-null   object
#  14  vote_average          4803 non-null   float64
# ...

# %% [markdown]
# ![Screenshot_2020-12-23 krishnaik06 Recommendation_complete_tutorial.png](data:image/png;base64,...)

# %%
particular_df = movies_cleaned_df[['vote_count', 'vote_average']]
particular_df.head()
# Out:
#    vote_count  vote_average
# 0       11800           7.2
# 1        4500           6.9
# 2        4466           6.3
# 3        9106           7.6
# 4        2124           6.1

# %%
particular_df['vote_count'].iloc[:250]
# Out:
# 0      11800
# 1       4500
# 2       4466
# 3       9106
# 4       2124
#        ...
# 245      925
# 246     1099
# 247     2124
# 248     2965
# 249     3829
# Name: vote_count, Length: 250, dtype: int64

# %%
# Calculate all the components based on the above formula
v=movies_cleaned_df['vote_count']
R=movies_cleaned_df['vote_average']
C=movies_cleaned_df['vote_average'].mean()
m=movies_cleaned_df['vote_count'].quantile(0.70)

# %%
movies_cleaned_df['weighted_average'] = ((R*v)+ (C*m))/(v+m)

# %%
movies_cleaned_df.head()
# Out:
#       budget  ... weighted_average
# 0  237000000  ...         7.148013
# 1  300000000  ...         6.807627
# 2  245000000  ...         6.276075
# 3  250000000  ...         7.509565
# 4  260000000  ...         6.098319
#
# [5 rows x 19 columns]

# %%
movie_sorted_ranking = movies_cleaned_df.sort_values('weighted_average',ascending=False)
movie_sorted_ranking.head()
# Out:
#          budget  ... weighted_average
# 1881   25000000  ...         8.340775
# 3337    6000000  ...         8.192887
# 662    63000000  ...         8.171648
# 3232    8000000  ...         8.157615
# 65    185000000  ...         8.102674
#
# [5 rows x 19 columns]

# %%
movie_sorted_ranking[['original_title', 'vote_count', 'vote_average', 'weighted_average', 'popularity']].head(20)
# Out:
#                                          original_title  ...  popularity
# 1881                           The Shawshank Redemption  ...  136.747729
# 3337                                      The Godfather  ...  143.659698
# 662                                          Fight Club  ...  146.757391
# 3232                                       Pulp Fiction  ...  121.463076
# 65                                      The Dark Knight  ...  187.322927
# 809                                        Forrest Gump  ...  138.133331
# 1818                                   Schindler's List  ...  104.469351
# 3865                                           Whiplash  ...  192.528841
# 96                                            Inception  ...  167.583710
# 1990                            The Empire Strikes Back  ...   78.517830
# 2294                                           千と千尋の神隠し  ...  118.968562
# 95                                         Interstellar  ...  724.247784
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.figure(figsize=(12,6))
axis1=sns.barplot(x=movie_sorted_ranking['weighted_average'].head(10), y=movie_sorted_ranking['original_title'].head(10), data=weight_average)
plt.xlim(4, 10)
plt.title('Best Movies by average votes', weight='bold')
plt.xlabel('Weighted Average Score', weight='bold')
plt.ylabel('Movie Title', weight='bold')
plt.savefig('best_movies.png')

# %%
plt.figure(figsize=(18,8))
popularity = movie_sorted_ranking.sort_values('popularity', ascending=False)
axis1=sns.barplot(x=popularity['popularity'].head(10), y=popularity['original_title'].head(10), data=weight_average)
plt.title('Best Movies by average votes', weight='bold')
plt.xlim(200, 900)
plt.xlabel('Weighted Average Score', weight='bold')
plt.ylabel('Movie Title', weight='bold')
plt.savefig('best_movies.png')

# %% [markdown]
# **Because to Scailing Our Data**

# %%
from sklearn.preprocessing import MinMaxScaler

scaling=MinMaxScaler()
movie_scaled_df=scaling.fit_transform(movies_cleaned_df[['weighted_average','popularity']])
movie_normalized_df=pd.DataFrame(movie_scaled_df,columns=['weighted_average','popularity'])
movie_normalized_df.head()
# Out:
#    weighted_average  popularity
# 0          0.674339    0.171815
# 1          0.581403    0.158846
# 2          0.436273    0.122635
# 3          0.773054    0.128272
# 4          0.387739    0.050169

# %%
movies_cleaned_df[['normalized_weight_average','normalized_popularity']]= movie_normalized_df

# %%
movies_cleaned_df.head()
# Out:
#       budget  ... normalized_popularity
# 0  237000000  ...              0.171815
# 1  300000000  ...              0.158846
# 2  245000000  ...              0.122635
# 3  250000000  ...              0.128272
# 4  260000000  ...              0.050169
#
# [5 rows x 21 columns]

# %% [markdown]
# #Recommendation based on scaled weighted average and popularity score(Priority is given 50% to both)

# %%
# basically i am doing here i am giving 50 50 percent to both important factors and then check the recomend and popular movies

# %%
movies_cleaned_df['score'] = movies_cleaned_df['normalized_weight_average'] * 0.5 + movies_cleaned_df['normalized_popularity'] * 0.5
movies_scored_df = movies_cleaned_df.sort_values(['score'], ascending=False)
movies_scored_df[['original_title', 'normalized_weight_average', 'normalized_popularity', 'score']].head(20)
# Out:
#                                          original_title  ...     score
# 95                                         Interstellar  ...  0.866801
# 546                                             Minions  ...  0.730315
# 94                              Guardians of the Galaxy  ...  0.700668
# 788                                            Deadpool  ...  0.656453
# 127                                  Mad Max: Fury Road  ...  0.583481
# 1881                           The Shawshank Redemption  ...  0.578090
# 65                                      The Dark Knight  ...  0.574466
# 3865                                           Whiplash  ...  0.568159
# 3337                                      The Godfather  ...  0.561848
# 662                                          Fight Club  ...  0.560717
# 96                                            Inception  ...  0.551718
# 3232                                       Pulp Fiction  ...  0.544357
# ...

# %%
plt.figure(figsize=(16,6))

scored_df = movies_scored_df.sort_values('score', ascending=False)

ax = sns.barplot(x=scored_df['score'].head(10), y=scored_df['original_title'].head(10), data=scored_df, palette='deep')

#plt.xlim(3.55, 5.25)
plt.title('Best Rated & Most Popular Blend', weight='bold')
plt.xlabel('Score', weight='bold')
plt.ylabel('Movie Title', weight='bold')

plt.savefig('scored_movies.png')

# %% [markdown]
# #Recommendation based on scaled weighted average and popularity score(Priority is given 75% to weighted_average and 25% To popularity)

# %%
movies_cleaned_df['score'] = movies_cleaned_df['normalized_weight_average'] * 0.75 + movies_cleaned_df['normalized_popularity'] * 0.25
movies_scored_df_2 = movies_cleaned_df.sort_values(['score'], ascending=False)
movies_scored_df_2[['original_title', 'normalized_weight_average', 'normalized_popularity', 'score']].head(20)
# Out:
#                                          original_title  ...     score
# 95                                         Interstellar  ...  0.886620
# 1881                           The Shawshank Redemption  ...  0.789045
# 94                              Guardians of the Galaxy  ...  0.776271
# 3337                                      The Godfather  ...  0.760735
# 662                                          Fight Club  ...  0.757270
# 65                                      The Dark Knight  ...  0.754729
# 3232                                       Pulp Fiction  ...  0.747174
# 3865                                           Whiplash  ...  0.742295
# 96                                            Inception  ...  0.731879
# 809                                        Forrest Gump  ...  0.731138
# 1818                                   Schindler's List  ...  0.717981
# 2294                                           千と千尋の神隠し  ...  0.716204
# ...

# %%
plt.figure(figsize=(16,6))

scored_df_2 = movies_scored_df_2.sort_values('score', ascending=False)

ax = sns.barplot(x=scored_df_2['score'].head(10), y=scored_df_2['original_title'].head(10), data=scored_df_2, palette='deep')

#plt.xlim(3.55, 5.25)
plt.title('Best Rated & Most Popular Blend', weight='bold')
plt.xlabel('Score', weight='bold')
plt.ylabel('Movie Title', weight='bold')

plt.savefig('scored_movies.png')

# %% [markdown]
# #Recommendation based on scaled weighted average and popularity score(Priority is given 75% to popularity and 25% To weighted_average)

# %%
movies_cleaned_df['score'] = movies_cleaned_df['normalized_weight_average'] * 0.25 + movies_cleaned_df['normalized_popularity'] * 0.75
movies_scored_df_3 = movies_cleaned_df.sort_values(['score'], ascending=False)
movies_scored_df_3[['original_title', 'normalized_weight_average', 'normalized_popularity', 'score']].head(20)
# Out:
#                                          original_title  ...     score
# 546                                             Minions  ...  0.865157
# 95                                         Interstellar  ...  0.846981
# 94                              Guardians of the Galaxy  ...  0.625065
# 788                                            Deadpool  ...  0.622071
# 127                                  Mad Max: Fury Road  ...  0.539735
# 28                                       Jurassic World  ...  0.481258
# 199   Pirates of the Caribbean: The Curse of the Bla...  ...  0.418196
# 65                                      The Dark Knight  ...  0.394204
# 3865                                           Whiplash  ...  0.394023
# 82                       Dawn of the Planet of the Apes  ...  0.378187
# 88                                           Big Hero 6  ...  0.377517
# 96                                            Inception  ...  0.371558
# ...

# %%
plt.figure(figsize=(16,6))

scored_df_3 = movies_scored_df_3.sort_values('score', ascending=False)

ax = sns.barplot(x=scored_df_3['score'].head(10), y=scored_df_3['original_title'].head(10), data=scored_df_3, palette='deep')

#plt.xlim(3.55, 5.25)
plt.title('Best Rated & Most Popular Blend', weight='bold')
plt.xlabel('Score', weight='bold')
plt.ylabel('Movie Title', weight='bold')

plt.savefig('scored_movies.png')

# %%
# Conclusion is that if we gave prefrence to popularity
# the Minions is the suggested movie.
# And if we gave prefrence to the voting_score, voting_rating
# the suggested movie is Interstellar.
